# %% [markdown]
# # csv

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv("ZILLOW-M550_SALES.csv")

# %%
df.head()
# Out:
#          Date  Value
# 0  2016-06-30   64.0
# 1  2016-05-31  163.0
# 2  2016-04-30  118.0
# 3  2016-03-31  110.0
# 4  2016-02-29   83.0

# %%
def arrange_time_dataframe(df):
    df.columns = ['date', 'value']
    df.sort_values(by='date', inplace=True)
    df.set_index('date', inplace=True)
    return df

# %%
df = arrange_time_dataframe(df)

# %%
df.head()
# Out:
#             value
# date
# 2008-06-30  100.0
# 2008-07-31  103.0
# 2008-08-31  112.0
# 2008-09-30   85.0
# 2008-10-31   88.0

# %%
df.plot(figsize=(16, 6))

# %% [markdown]
# # JSON

# %%
import json

# %%
with open("M550_SALES.json") as f:
    data = json.load(f)

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "dataset": {
#     "id": 35366971,
#     "dataset_code": "M550_SALES",
#     "database_code": "ZILLOW",
#     "name": "Zillow Home Value Index (Metro): Home Sales (NSA) - Morehead City, NC",
#     "description": "The Zillow Home Value Index is Zillow's estimate of the median market value of home sales (nsa) within the metro of Morehead City, NC. This data is calculated by Zillow Real Estate Research (www.zillow.com/research) using their database of 110 million homes.",
#     "refreshed_at": "2017-05-24T05:14:00.443Z",
#     "newest_available_date": "2016-06-30",
#     "oldest_available_date": "2008-06-30",
#     "column_names": [
#       "Date",
#       "Value"
#     ],
#     "frequency": "monthly",
#     "type": "Time Series",
#     "premium": false,
#     "limit": null,
#     "transform": null,
#     "column_index": null,
#     "start_date": "2008-06-30",
#     "end_date": "2016-06-30",
#     "data": [
#       [
#         "2016-06-30",
#         64.0
#       ],
#       [
#         "2016-05-31",
#         163.0
#       ],
#       [
#         "2016-04-30",
#         118.0
#       ],
#       [
#         "2016-03-31",
#         110.0
#       ],
#       [
#         "2016-02-29",
#         83.0
#       ],
#       [
#         "2016-01-31",
#         82.0
#       ],
#       [
#         "2015-12-31",
#         123.0
#       ],
#       [
#         "2015-11-30",
#         98.0
#       ],
#       [
#         "2015-10-31",
#         123.0
#       ],
#       [
#         "2015-09-30",
#         123.0
#       ],
#       [
#         "2015-08-31",
#         152.0
#       ],
#       [
#         "2015-07-31",
#         159.0
#       ],
#       [
#         "2015-06-30",
#         162.0
#       ],
#       [
#         "2015-05-31",
#         129.0
#       ],
#       [
#         "2015-04-30",
#         124.0
#       ],
#       [
#         "2015-03-31",
#         107.0
#       ],
#       [
#         "2015-02-28",
#         89.0
#       ],
#       [
#         "2015-01-31",
#         76.0
#       ],
#       [
#         "2014-12-31",
#         115.0
#       ],
#       [
#         "2014-11-30",
#         89.0
#       ],
#       [
#         "2014-10-31",
#         124.0
#       ],
#       [
#         "2014-09-30",
#         145.0
#       ],
#       [
#         "2014-08-31",
#         139.0
#       ],
#       [
#         "2014-07-31",
#         116.0
#       ],
#       [
#         "2014-06-30",
#         130.0
#       ],
#       [
#         "2014-05-31",
#         96.0
#       ],
#       [
#         "2014-04-30",
#         97.0
#       ],
#       [
#         "2014-03-31",
#         95.0
#       ],
#       [
#         "2014-02-28",
#         62.0
#       ],
#       [
#         "2014-01-31",
#         62.0
#       ],
#       [
#         "2013-12-31",
#         101.0
#       ],
#       [
#         "2013-11-30",
#         76.0
#       ],
#       [
#         "2013-10-31",
#         99.0
#       ],
#       [
#         "2013-09-30",
#         104.0
#       ],
#       [
#         "2013-08-31",
#         122.0
#       ],
#       [
#         "2013-07-31",
#         127.0
#       ],
#       [
#         "2013-06-30",
#         121.0
#       ],
#       [
#         "2013-05-31",
#         122.0
#       ],
#       [
#         "2013-04-30",
#         138.0
#       ],
#       [
#         "2013-03-31",
#         109.0
#       ],
#       [
#         "2013-02-28",
#         79.0
#       ],
#       [
#         "2013-01-31",
#         74.0
#       ],
#       [
#         "2012-12-31",
#         116.0
#       ],
#       [
#         "2012-11-30",
#         108.0
#       ],
#       [
#         "2012-10-31",
#         116.0
#       ],
#       [
#         "2012-09-30",
#         104.0
#       ],
#       [
#         "2012-08-31",
#         114.0
#       ],
#       [
#         "2012-07-31",
#         116.0
#       ],
#       [
#         "2012-06-30",
#         108.0
#       ],
#       [
#         "2012-05-31",
#         97.0
#       ],
#       [
#         "2012-04-30",
#         92.0
#       ],
#       [
#         "2012-03-31",
#         102.0
#       ],
#       [
#         "2012-02-29",
#         61.0
#       ],
#       [
#         "2012-01-31",
#         65.0
#       ],
#       [
#         "2011-12-31",
#         78.0
#       ],
#       [
#         "2011-11-30",
#         60.0
#       ],
#       [
#         "2011-10-31",
#         68.0
#       ],
#       [
#         "2011-09-30",
#         96.0
#       ],
#       [
#         "2011-08-31",
#         78.0
#       ],
#       [
#         "2011-07-31",
#         89.0
#       ],
#       [
#         "2011-06-30",
#         88.0
#       ],
#       [
#         "2011-05-31",
#         82.0
#       ],
#       [
#         "2011-04-30",
#         86.0
#       ],
#       [
#         "2011-03-31",
#         93.0
#       ],
#       [
#         "2011-02-28",
#         69.0
#       ],
#       [
#         "2011-01-31",
#         57.0
#       ],
#       [
#         "2010-12-31",
#         81.0
#       ],
#       [
#         "2010-11-30",
#         60.0
#       ],
#       [
#         "2010-10-31",
#         73.0
#       ],
#       [
#         "2010-09-30",
#         78.0
#       ],
#       [
#         "2010-08-31",
#         82.0
#       ],
#       [
#         "2010-07-31",
#         90.0
#       ],
#       [
#         "2010-06-30",
#         94.0
#       ],
#       [
#         "2010-05-31",
#         98.0
#       ],
#       [
#         "2010-04-30",
#         106.0
#       ],
#       [
#         "2010-03-31",
#         82.0
#       ],
#       [
#         "2010-02-28",
#         54.0
#       ],
#       [
#         "2010-01-31",
#         62.0
#       ],
#       [
#         "2009-12-31",
#         75.0
#       ],
#       [
#         "2009-11-30",
#         75.0
#       ],
#       [
#         "2009-10-31",
#         74.0
#       ],
#       [
#         "2009-09-30",
#         81.0
#       ],
#       [
#         "2009-08-31",
#         71.0
#       ],
#       [
#         "2009-07-31",
#         85.0
#       ],
#       [
#         "2009-06-30",
#         92.0
#       ],
#       [
#         "2009-05-31",
#         87.0
#       ],
#       [
#         "2009-04-30",
#         80.0
#       ],
#       [
#         "2009-03-31",
#         68.0
#       ],
#       [
#         "2009-02-28",
#         57.0
#       ],
#       [
#         "2009-01-31",
#         53.0
#       ],
#       [
#         "2008-12-31",
#         61.0
#       ],
#       [
#         "2008-11-30",
#         46.0
#       ],
#       [
#         "2008-10-31",
#         88.0
#       ],
#       [
#         "2008-09-30",
#         85.0
#       ],
#       [
#         "2008-08-31",
#         112.0
#       ],
#       [
#         "2008-07-31",
#         103.0
#       ],
#       [
#         "2008-06-30",
#         100.0
#       ]
#     ],
#     "collapse": null,
#     "order": null,
#     "database_id": 15209
#   }
# }

# %%
data['dataset']
# Out:
# {'id': 35366971,
#  'dataset_code': 'M550_SALES',
#  'database_code': 'ZILLOW',
#  'name': 'Zillow Home Value Index (Metro): Home Sales (NSA) - Morehead City, NC',
#  'description': "The Zillow Home Value Index is Zillow's estimate of the median market value of home sales (nsa) within the metro of Morehead City, NC. This data is calculated by Zillow Real Estate Research (www.zillow.com/research) using their database of 110 million homes.",
#  'refreshed_at': '2017-05-24T05:14:00.443Z',
#  'newest_available_date': '2016-06-30',
#  'oldest_available_date': '2008-06-30',
#  'column_names': ['Date', 'Value'],
#  'frequency': 'monthly',
#  'type': 'Time Series',
#  'premium': False,
#  'limit': None,
#  'transform': None,
#  'column_index': None,
#  'start_date': '2008-06-30',
#  'end_date': '2016-06-30',
#  'data': [['2016-06-30', 64.0],
#   ['2016-05-31', 163.0],
#   ['2016-04-30', 118.0],
#   ['2016-03-31', 110.0],
#   ['2016-02-29', 83.0],
#   ['2016-01-31', 82.0],
#   ['2015-12-31', 123.0],
#   ['2015-11-30', 98.0],
#   ['2015-10-31', 123.0],
#   ['2015-09-30', 123.0],
#   ['2015-08-31', 152.0],
#   ['2015-07-31', 159.0],
#   ['2015-06-30', 162.0],
#   ['2015-05-31', 129.0],
#   ['2015-04-30', 124.0],
#   ['2015-03-31', 107.0],
#   ['2015-02-28', 89.0],
#   ['2015-01-31', 76.0],
#   ['2014-12-31', 115.0],
#   ['2014-11-30', 89.0],
#   ['2014-10-31', 124.0],
#   ['2014-09-30', 145.0],
#   ['2014-08-31', 139.0],
#   ['2014-07-31', 116.0],
#   ['2014-06-30', 130.0],
#   ['2014-05-31', 96.0],
#   ['2014-04-30', 97.0],
#   ['2014-03-31', 95.0],
#   ['2014-02-28', 62.0],
#   ['2014-01-31', 62.0],
#   ['2013-12-31', 101.0],
#   ['2013-11-30', 76.0],
#   ['2013-10-31', 99.0],
#   ['2013-09-30', 104.0],
#   ['2013-08-31', 122.0],
#   ['2013-07-31', 127.0],
#   ['2013-06-30', 121.0],
#   ['2013-05-31', 122.0],
#   ['2013-04-30', 138.0],
#   ['2013-03-31', 109.0],
#   ['2013-02-28', 79.0],
#   ['2013-01-31', 74.0],
#   ['2012-12-31', 116.0],
#   ['2012-11-30', 108.0],
#   ['2012-10-31', 116.0],
#   ['2012-09-30', 104.0],
#   ['2012-08-31', 114.0],
#   ['2012-07-31', 116.0],
#   ['2012-06-30', 108.0],
#   ['2012-05-31', 97.0],
#   ['2012-04-30', 92.0],
#   ['2012-03-31', 102.0],
#   ['2012-02-29', 61.0],
#   ['2012-01-31', 65.0],
#   ['2011-12-31', 78.0],
#   ['2011-11-30', 60.0],
#   ['2011-10-31', 68.0],
#   ['2011-09-30', 96.0],
#   ['2011-08-31', 78.0],
#   ['2011-07-31', 89.0],
#   ['2011-06-30', 88.0],
#   ['2011-05-31', 82.0],
#   ['2011-04-30', 86.0],
#   ['2011-03-31', 93.0],
#   ['2011-02-28', 69.0],
#   ['2011-01-31', 57.0],
#   ['2010-12-31', 81.0],
#   ['2010-11-30', 60.0],
#   ['2010-10-31', 73.0],
#   ['2010-09-30', 78.0],
#   ['2010-08-31', 82.0],
#   ['2010-07-31', 90.0],
#   ['2010-06-30', 94.0],
#   ['2010-05-31', 98.0],
#   ['2010-04-30', 106.0],
#   ['2010-03-31', 82.0],
#   ['2010-02-28', 54.0],
#   ['2010-01-31', 62.0],
#   ['2009-12-31', 75.0],
#   ['2009-11-30', 75.0],
#   ['2009-10-31', 74.0],
#   ['2009-09-30', 81.0],
#   ['2009-08-31', 71.0],
#   ['2009-07-31', 85.0],
#   ['2009-06-30', 92.0],
#   ['2009-05-31', 87.0],
#   ['2009-04-30', 80.0],
#   ['2009-03-31', 68.0],
#   ['2009-02-28', 57.0],
#   ['2009-01-31', 53.0],
#   ['2008-12-31', 61.0],
#   ['2008-11-30', 46.0],
#   ['2008-10-31', 88.0],
#   ['2008-09-30', 85.0],
#   ['2008-08-31', 112.0],
#   ['2008-07-31', 103.0],
#   ['2008-06-30', 100.0]],
#  'collapse': None,
#  'order': None,
#  'database_id': 15209}

# %%
data['dataset']['data']
# Out:
# [['2016-06-30', 64.0],
#  ['2016-05-31', 163.0],
#  ['2016-04-30', 118.0],
#  ['2016-03-31', 110.0],
#  ['2016-02-29', 83.0],
#  ['2016-01-31', 82.0],
#  ['2015-12-31', 123.0],
#  ['2015-11-30', 98.0],
#  ['2015-10-31', 123.0],
#  ['2015-09-30', 123.0],
#  ['2015-08-31', 152.0],
#  ['2015-07-31', 159.0],
#  ['2015-06-30', 162.0],
#  ['2015-05-31', 129.0],
#  ['2015-04-30', 124.0],
#  ['2015-03-31', 107.0],
#  ['2015-02-28', 89.0],
#  ['2015-01-31', 76.0],
#  ['2014-12-31', 115.0],
#  ['2014-11-30', 89.0],
#  ['2014-10-31', 124.0],
#  ['2014-09-30', 145.0],
#  ['2014-08-31', 139.0],
#  ['2014-07-31', 116.0],
#  ['2014-06-30', 130.0],
#  ['2014-05-31', 96.0],
#  ['2014-04-30', 97.0],
#  ['2014-03-31', 95.0],
#  ['2014-02-28', 62.0],
#  ['2014-01-31', 62.0],
#  ['2013-12-31', 101.0],
#  ['2013-11-30', 76.0],
#  ['2013-10-31', 99.0],
#  ['2013-09-30', 104.0],
#  ['2013-08-31', 122.0],
#  ['2013-07-31', 127.0],
#  ['2013-06-30', 121.0],
#  ['2013-05-31', 122.0],
#  ['2013-04-30', 138.0],
#  ['2013-03-31', 109.0],
#  ['2013-02-28', 79.0],
#  ['2013-01-31', 74.0],
#  ['2012-12-31', 116.0],
#  ['2012-11-30', 108.0],
#  ['2012-10-31', 116.0],
#  ['2012-09-30', 104.0],
#  ['2012-08-31', 114.0],
#  ['2012-07-31', 116.0],
#  ['2012-06-30', 108.0],
#  ['2012-05-31', 97.0],
#  ['2012-04-30', 92.0],
#  ['2012-03-31', 102.0],
#  ['2012-02-29', 61.0],
#  ['2012-01-31', 65.0],
#  ['2011-12-31', 78.0],
#  ['2011-11-30', 60.0],
#  ['2011-10-31', 68.0],
#  ['2011-09-30', 96.0],
#  ['2011-08-31', 78.0],
#  ['2011-07-31', 89.0],
#  ['2011-06-30', 88.0],
#  ['2011-05-31', 82.0],
#  ['2011-04-30', 86.0],
#  ['2011-03-31', 93.0],
#  ['2011-02-28', 69.0],
#  ['2011-01-31', 57.0],
#  ['2010-12-31', 81.0],
#  ['2010-11-30', 60.0],
#  ['2010-10-31', 73.0],
#  ['2010-09-30', 78.0],
#  ['2010-08-31', 82.0],
#  ['2010-07-31', 90.0],
#  ['2010-06-30', 94.0],
#  ['2010-05-31', 98.0],
#  ['2010-04-30', 106.0],
#  ['2010-03-31', 82.0],
#  ['2010-02-28', 54.0],
#  ['2010-01-31', 62.0],
#  ['2009-12-31', 75.0],
#  ['2009-11-30', 75.0],
#  ['2009-10-31', 74.0],
#  ['2009-09-30', 81.0],
#  ['2009-08-31', 71.0],
#  ['2009-07-31', 85.0],
#  ['2009-06-30', 92.0],
#  ['2009-05-31', 87.0],
#  ['2009-04-30', 80.0],
#  ['2009-03-31', 68.0],
#  ['2009-02-28', 57.0],
#  ['2009-01-31', 53.0],
#  ['2008-12-31', 61.0],
#  ['2008-11-30', 46.0],
#  ['2008-10-31', 88.0],
#  ['2008-09-30', 85.0],
#  ['2008-08-31', 112.0],
#  ['2008-07-31', 103.0],
#  ['2008-06-30', 100.0]]

# %%
df1 = pd.DataFrame(data['dataset']['data'])

# %%
df1.head()
# Out:
#             0      1
# 0  2016-06-30   64.0
# 1  2016-05-31  163.0
# 2  2016-04-30  118.0
# 3  2016-03-31  110.0
# 4  2016-02-29   83.0

# %%
df1 = arrange_time_dataframe(df1)

# %%
df1.plot(figsize=(16, 6))

# %% [markdown]
# # XML

# %%
with open("M550_SALES.xml") as f:
    data = f.read()

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data, "lxml")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-23-8365e2a717af> in <module>
# ----> 1 soup = BeautifulSoup(data, "lxml")
#
# c:\users\zheng\appdata\local\programs\python\python37\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     206                     "Couldn't find a tree builder with the features you "
#     207                     "requested: %s. Do you need to install a parser library?"
# --> 208                     % ",".join(features))
#     209
#     210         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
dates = soup.find_all('datum', type='date')

# %%
dates[:5]

# %%
dates = [item.text for item in dates]

# %%
dates[:5]

# %%
values= soup.find_all('datum', type='float')

# %%
values[:5]

# %%
values = [float(item.text) for item in values]

# %%
values[:5]

# %%
df2 = pd.DataFrame({'dates':dates, 'values':values})

# %%
df2.head()

# %%
df2 = arrange_time_dataframe(df2)

# %%
df2.plot(figsize=(16, 6))
